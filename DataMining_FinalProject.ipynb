# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline
import collections
import math

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score as acs
from sklearn.svm import SVC

# %%
from prettytable import PrettyTable
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.callbacks import EarlyStopping
from keras.layers.core import Dense,Activation,Dropout
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Pre-Processing of the data

# %% [markdown]
# ## Dataset Used (Breast Cancer Diagnostic)

# %%
data=pd.read_csv("data.csv")
data.drop(["Unnamed: 32","id"],axis=1,inplace=True)
display(data.head(20))
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M        17.99         10.38          122.80     1001.0
# 1          M        20.57         17.77          132.90     1326.0
# 2          M        19.69         21.25          130.00     1203.0
# 3          M        11.42         20.38           77.58      386.1
# 4          M        20.29         14.34          135.10     1297.0
# 5          M        12.45         15.70           82.57      477.1
# 6          M        18.25         19.98          119.60     1040.0
# 7          M        13.71         20.83           90.20      577.9
# 8          M        13.00         21.82           87.50      519.8
# 9          M        12.46         24.04           83.97      475.9
# 10         M        16.02         23.24          102.70      797.8
# 11         M        15.78         17.89          103.60      781.0
# 12         M        19.17         24.80          132.40     1123.0
# 13         M        15.85         23.95          103.70      782.7
# 14         M        13.73         22.61           93.60      578.3
# 15         M        14.54         27.54           96.73      658.8
# 16         M        14.68         20.13           94.74      684.5
# 17         M        16.13         20.68          108.10      798.8
# 18         M        19.81         22.15          130.00     1260.0
# 19         B        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760         0.30010              0.14710
# 1           0.08474           0.07864         0.08690              0.07017
# 2           0.10960           0.15990         0.19740              0.12790
# 3           0.14250           0.28390         0.24140              0.10520
# 4           0.10030           0.13280         0.19800              0.10430
# 5           0.12780           0.17000         0.15780              0.08089
# 6           0.09463           0.10900         0.11270              0.07400
# 7           0.11890           0.16450         0.09366              0.05985
# 8           0.12730           0.19320         0.18590              0.09353
# 9           0.11860           0.23960         0.22730              0.08543
# 10          0.08206           0.06669         0.03299              0.03323
# 11          0.09710           0.12920         0.09954              0.06606
# 12          0.09740           0.24580         0.20650              0.11180
# 13          0.08401           0.10020         0.09938              0.05364
# 14          0.11310           0.22930         0.21280              0.08025
# 15          0.11390           0.15950         0.16390              0.07364
# 16          0.09867           0.07200         0.07395              0.05259
# 17          0.11700           0.20220         0.17220              0.10280
# 18          0.09831           0.10270         0.14790              0.09498
# 19          0.09779           0.08129         0.06664              0.04781
#
#     symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0          0.2419  ...         25.38          17.33           184.60
# 1          0.1812  ...         24.99          23.41           158.80
# 2          0.2069  ...         23.57          25.53           152.50
# 3          0.2597  ...         14.91          26.50            98.87
# 4          0.1809  ...         22.54          16.67           152.20
# 5          0.2087  ...         15.47          23.75           103.40
# 6          0.1794  ...         22.88          27.66           153.20
# 7          0.2196  ...         17.06          28.14           110.60
# 8          0.2350  ...         15.49          30.73           106.20
# 9          0.2030  ...         15.09          40.68            97.65
# 10         0.1528  ...         19.19          33.88           123.80
# 11         0.1842  ...         20.42          27.28           136.50
# 12         0.2397  ...         20.96          29.94           151.70
# 13         0.1847  ...         16.84          27.66           112.00
# 14         0.2069  ...         15.03          32.01           108.80
# 15         0.2303  ...         17.46          37.13           124.10
# 16         0.1586  ...         19.07          30.88           123.40
# 17         0.2164  ...         20.96          31.48           136.80
# 18         0.1582  ...         27.32          30.88           186.80
# 19         0.1885  ...         15.11          19.26            99.70
#
#     area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       2019.0            0.1622             0.6656           0.7119
# 1       1956.0            0.1238             0.1866           0.2416
# 2       1709.0            0.1444             0.4245           0.4504
# 3        567.7            0.2098             0.8663           0.6869
# 4       1575.0            0.1374             0.2050           0.4000
# 5        741.6            0.1791             0.5249           0.5355
# 6       1606.0            0.1442             0.2576           0.3784
# 7        897.0            0.1654             0.3682           0.2678
# 8        739.3            0.1703             0.5401           0.5390
# 9        711.4            0.1853             1.0580           1.1050
# 10      1150.0            0.1181             0.1551           0.1459
# 11      1299.0            0.1396             0.5609           0.3965
# 12      1332.0            0.1037             0.3903           0.3639
# 13       876.5            0.1131             0.1924           0.2322
# 14       697.7            0.1651             0.7725           0.6943
# 15       943.2            0.1678             0.6577           0.7026
# 16      1138.0            0.1464             0.1871           0.2914
# 17      1315.0            0.1789             0.4233           0.4784
# 18      2398.0            0.1512             0.3150           0.5372
# 19       711.2            0.1440             0.1773           0.2390
#
#     concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.26540          0.4601                  0.11890
# 1                0.18600          0.2750                  0.08902
# 2                0.24300          0.3613                  0.08758
# 3                0.25750          0.6638                  0.17300
# 4                0.16250          0.2364                  0.07678
# 5                0.17410          0.3985                  0.12440
# 6                0.19320          0.3063                  0.08368
# 7                0.15560          0.3196                  0.11510
# 8                0.20600          0.4378                  0.10720
# 9                0.22100          0.4366                  0.20750
# 10               0.09975          0.2948                  0.08452
# 11               0.18100          0.3792                  0.10480
# 12               0.17670          0.3176                  0.10230
# 13               0.11190          0.2809                  0.06287
# 14               0.22080          0.3596                  0.14310
# 15               0.17120          0.4218                  0.13410
# 16               0.16090          0.3029                  0.08216
# 17               0.20730          0.3706                  0.11420
# 18               0.23880          0.2768                  0.07615
# 19               0.12880          0.2977                  0.07259
#
# [20 rows x 31 columns]

# %%
data.shape
# Out:
# (569, 31)

# %%
X=data.iloc[:,1:32]
y=data.iloc[:,0]

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %% [markdown]
# # Function To Calcuate Metrices

# %% [markdown]
# # ML Models

# %%
def data_met(tn, fp, fn, tp):
    result = []
    result.append(tn)
    result.append(fp)
    result.append(fn)
    result.append(tp)
    tpr = tp/(tp+fn)
    result.append(tpr)
    tnr = tn/(tn+fp)
    result.append(tnr)
    fpr = fp/(tn+fp)
    result.append(fpr)
    fnr = fn/(tp+fn)
    result.append(fnr)
    recall = tp/(tp+fn)
    result.append(recall)
    precision = tp/(tp+fp)
    result.append(precision)
    f1 = (2*tp)/(2*tp+fp+fn)
    result.append(f1)
    acc = (tp+tn)/(tp+fp+fn+tn)
    result.append(acc)
    err = (fp+fn)/(tp+fp+fn+tn)
    result.append(err)
    bacc = (tpr+tnr)/2
    result.append(bacc)
    tss = tp/(tp+fn) - fp/(fp+tn)
    result.append(tss)
    hss = 2*(tp*tn - fp*fn)/((tp+fn)*(fn+tn) + (tp+fp)*(fp+tn))
    result.append(hss)
    return np.array(result)

# %%
cross_validation_folds = KFold(n_splits=10,shuffle=True, random_state=3030)
fold = 0
for train_index, test_index in cross_validation_folds.split(X, y):
    fold += 1
    print("Fold", str(fold))
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    #Random Forrest
    print("\tRandom Forest model result:")
    rf = RandomForestClassifier(max_depth=5, random_state=0)
    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict(X_test)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred_rf).ravel()
    rf_result = data_met(tn, fp, fn, tp)
    print("\t\tTrue negative:", rf_result[0])
    print("\t\tFalse positive:", rf_result[1])
    print("\t\tFalse negative:", rf_result[2])
    print("\t\tTrue positive:", rf_result[3])
    print("\t\tTrue positive rate:", rf_result[4])
    print("\t\tTrue negative rate:", rf_result[5])
    print("\t\tFalse positive rate:", rf_result[6])
    print("\t\tFalse negative rate:", rf_result[7])
    print("\t\tRecall:", rf_result[8])
    print("\t\tPrecision:", rf_result[9])
    print("\t\tF1:", rf_result[10])
    print("\t\tAccuracy:", rf_result[11])
    print("\t\tError Rate:", rf_result[12]) 
    print("\t\tBalance Accuracy:", rf_result[13])
    print("\t\tTrue skill statistics:", rf_result[14])
    print("\t\tHeidke skill score:", rf_result[15])
     #SVM
    print("\tSVM model result:")
    svc = SVC(gamma='auto')
    svc.fit(X_train, y_train)
    y_pred_svc = svc.predict(X_test)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred_svc).ravel()
    svc_result = data_met(tn, fp, fn, tp)
    print("\t\tTrue negative:", svc_result[0])
    print("\t\tFalse positive:", svc_result[1])
    print("\t\tFalse negative:", svc_result[2])
    print("\t\tTrue positive:", svc_result[3])
    print("\t\tTrue positive rate:", svc_result[4])
    print("\t\tTrue negative rate:", svc_result[5])
    print("\t\tFalse positive rate:", svc_result[6])
    print("\t\tFalse negative rate:", svc_result[7])
    print("\t\tRecall:", svc_result[8])
    print("\t\tPrecision:", svc_result[9])
    print("\t\tF1:", svc_result[10])
    print("\t\tAccuracy:", svc_result[11])
    print("\t\tError Rate:", svc_result[12]) 
    print("\t\tBalance Accuracy:", svc_result[13])
    print("\t\tTrue skill statistics:", svc_result[14])
    print("\t\tHeidke skill score:", svc_result[15])
    print("\n\n")
    ##lstm
    #print (X[:5])
    #print (y[:5],set(y))
    #print (y[:5],set(y))
    
    
    X_bar = X.copy()
    y_bar = np.array([1 if k == 'B' else 0 for k in list(y)])
    
    X_train_fold = np.array(X_bar[train_index])
    y_train_fold = np.array(y_bar[train_index]).reshape(-1,1).astype(int)
    X_val_fold = np.array(X_bar[test_index])
    y_val_fold = np.array(y_bar[test_index]).reshape(-1,1).astype(int)
    
    X_train_fold = np.reshape(X_train_fold,(X_train_fold.shape[0], 1, X_train_fold.shape[1])).astype(int)
    X_val_fold = np.reshape(X_val_fold, (X_val_fold.shape[0], 1, X_val_fold.shape[1])).astype(int)
    
    model = Sequential()

    model.add(LSTM(60, return_sequences=True, input_shape=(1,30)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.add(Activation('Softmax'))
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
    history = model.fit(X_train_fold, y_train_fold, epochs=5, batch_size=20, validation_data=(X_val_fold, y_val_fold),
                        verbose=1, shuffle=False)
    
    ## Report LSTM Result
    y_pred_lstm = model.predict(X_val_fold)
    y_pred_lstm = np.array([t[0][0] for t in y_pred_lstm]).ravel()
    y_val_fold = np.array(y_bar[test_index]).ravel()
    tn, fp, fn, tp = confusion_matrix(y_val_fold, y_pred_lstm).ravel()
    lstm_result = data_met(tn, fp, fn, tp)
    print("LSTM:\n\n")
    print("\t\tTrue negative:", lstm_result[0])
    print("\t\tFalse positive:", lstm_result[1])
    print("\t\tFalse negative:", lstm_result[2])
    print("\t\tTrue positive:", lstm_result[3])
    print("\t\tTrue positive rate:", lstm_result[4])
    print("\t\tTrue negative rate:", lstm_result[5])
    print("\t\tFalse positive rate:", lstm_result[6])
    print("\t\tFalse negative rate:", lstm_result[7])
    print("\t\tRecall:", lstm_result[8])
    print("\t\tPrecision:", lstm_result[9])
    print("\t\tF1:", lstm_result[10])
    print("\t\tAccuracy:", lstm_result[11])
    print("\t\tError Rate:", lstm_result[12]) 
    print("\t\tBalance Accuracy:", lstm_result[13])
    print("\t\tTrue skill statistics:", lstm_result[14])
    print("\t\tHeidke skill score:", lstm_result[15])
    
    
    table=PrettyTable()
    table.field_names = ['Model','TN','FP','FN','TP','TPR','TNR','FPR','FNR','recall','precision','F1','accuracy','ER','BA','TSS','HSS']
    table.add_row(['RandomForest',rf_result[0],rf_result[1],rf_result[2],rf_result[3],rf_result[4],rf_result[5],rf_result[6],rf_result[7],rf_result[8],rf_result[9],rf_result[10],rf_result[11],rf_result[12],rf_result[13],rf_result[14],rf_result[15]])
    table.add_row(['SVM',svc_result[0],svc_result[1],svc_result[2],svc_result[3],svc_result[4],svc_result[5],svc_result[6],svc_result[7],svc_result[8],svc_result[9],svc_result[10],svc_result[11],svc_result[12],svc_result[13],svc_result[14],svc_result[15]])
    table.add_row(['lstm',lstm_result[0],lstm_result[1],lstm_result[2],lstm_result[3],lstm_result[4],lstm_result[5],lstm_result[6],lstm_result[7],lstm_result[8],lstm_result[9],svc_result[10],lstm_result[11],lstm_result[12],lstm_result[13],lstm_result[14],lstm_result[15]])
    print(table)
    print("\n\n")
# Out:
# Fold 1
# 	Random Forest model result:
# 		True negative: 33.0
# 		False positive: 0.0
# 		False negative: 3.0
# 		True positive: 21.0
# 		True positive rate: 0.875
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.125
# 		Recall: 0.875
# 		Precision: 1.0
# 		F1: 0.9333333333333333
# 		Accuracy: 0.9473684210526315
# 		Error Rate: 0.05263157894736842
# 		Balance Accuracy: 0.9375
# 		True skill statistics: 0.875
# 		Heidke skill score: 0.8901734104046243
# 	SVM model result:
# 		True negative: 32.0
# 		False positive: 1.0
# 		False negative: 0.0
# 		True positive: 24.0
# 		True positive rate: 1.0
# 		True negative rate: 0.9696969696969697
# 		False positive rate: 0.030303030303030304
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.96
# 		F1: 0.9795918367346939
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9848484848484849
# 		True skill statistics: 0.9696969696969697
# 		Heidke skill score: 0.9642184557438794
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 8s 86ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 3/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 4/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 24.0
# 		False negative: 0.0
# 		True positive: 33.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.5789473684210527
# 		F1: 0.7333333333333333
# 		Accuracy: 0.5789473684210527
# 		Error Rate: 0.42105263157894735
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+-------+--------------------+----------------------+-------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |  TPR  |        TNR         |         FPR          |  FNR  | recall |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+-------+--------------------+----------------------+-------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 33.0 | 0.0  | 3.0 | 21.0 | 0.875 |        1.0         |         0.0          | 0.125 | 0.875  |        1.0         | 0.9333333333333333 | 0.9473684210526315 | 0.05263157894736842  |       0.9375       |       0.875        | 0.8901734104046243 |
# |     SVM      | 32.0 | 1.0  | 0.0 | 24.0 |  1.0  | 0.9696969696969697 | 0.030303030303030304 |  0.0  |  1.0   |        0.96        | 0.9795918367346939 | 0.9824561403508771 | 0.017543859649122806 | 0.9848484848484849 | 0.9696969696969697 | 0.9642184557438794 |
# |     lstm     | 0.0  | 24.0 | 0.0 | 33.0 |  1.0  |        0.0         |         1.0          |  0.0  |  1.0   | 0.5789473684210527 | 0.9795918367346939 | 0.5789473684210527 | 0.42105263157894735  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+-------+--------------------+----------------------+-------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 2
# 	Random Forest model result:
# 		True negative: 35.0
# 		False positive: 4.0
# 		False negative: 1.0
# 		True positive: 17.0
# 		True positive rate: 0.9444444444444444
# 		True negative rate: 0.8974358974358975
# 		False positive rate: 0.10256410256410256
# 		False negative rate: 0.05555555555555555
# 		Recall: 0.9444444444444444
# 		Precision: 0.8095238095238095
# 		F1: 0.8717948717948718
# 		Accuracy: 0.9122807017543859
# 		Error Rate: 0.08771929824561403
# 		Balance Accuracy: 0.920940170940171
# 		True skill statistics: 0.8418803418803419
# 		Heidke skill score: 0.8057259713701431
# 	SVM model result:
# 		True negative: 39.0
# 		False positive: 0.0
# 		False negative: 0.0
# 		True positive: 18.0
# 		True positive rate: 1.0
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 1.0
# 		F1: 1.0
# 		Accuracy: 1.0
# 		Error Rate: 0.0
# 		Balance Accuracy: 1.0
# 		True skill statistics: 1.0
# 		Heidke skill score: 1.0
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 8s 95ms/step - loss: 5.7780 - accuracy: 0.6211 - val_loss: 4.8155 - val_accuracy: 0.6842
# Epoch 2/5
# 26/26 [==============================] - 0s 11ms/step - loss: 5.7780 - accuracy: 0.6211 - val_loss: 4.8155 - val_accuracy: 0.6842
# Epoch 3/5
# 26/26 [==============================] - 0s 17ms/step - loss: 5.7780 - accuracy: 0.6211 - val_loss: 4.8155 - val_accuracy: 0.6842
# Epoch 4/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.7780 - accuracy: 0.6211 - val_loss: 4.8155 - val_accuracy: 0.6842
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7780 - accuracy: 0.6211 - val_loss: 4.8155 - val_accuracy: 0.6842
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 18.0
# 		False negative: 0.0
# 		True positive: 39.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.6842105263157895
# 		F1: 0.8125
# 		Accuracy: 0.6842105263157895
# 		Error Rate: 0.3157894736842105
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+-------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         |        TNR         |         FPR         |         FNR         |       recall       |     precision      |         F1         |      accuracy      |          ER         |         BA        |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+-------------------+--------------------+--------------------+
# | RandomForest | 35.0 | 4.0  | 1.0 | 17.0 | 0.9444444444444444 | 0.8974358974358975 | 0.10256410256410256 | 0.05555555555555555 | 0.9444444444444444 | 0.8095238095238095 | 0.8717948717948718 | 0.9122807017543859 | 0.08771929824561403 | 0.920940170940171 | 0.8418803418803419 | 0.8057259713701431 |
# |     SVM      | 39.0 | 0.0  | 0.0 | 18.0 |        1.0         |        1.0         |         0.0         |         0.0         |        1.0         |        1.0         |        1.0         |        1.0         |         0.0         |        1.0        |        1.0         |        1.0         |
# |     lstm     | 0.0  | 18.0 | 0.0 | 39.0 |        1.0         |        0.0         |         1.0         |         0.0         |        1.0         | 0.6842105263157895 |        1.0         | 0.6842105263157895 |  0.3157894736842105 |        0.5        |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+-------------------+--------------------+--------------------+
#
#
#
# Fold 3
# 	Random Forest model result:
# 		True negative: 35.0
# 		False positive: 1.0
# 		False negative: 1.0
# 		True positive: 20.0
# 		True positive rate: 0.9523809523809523
# 		True negative rate: 0.9722222222222222
# 		False positive rate: 0.027777777777777776
# 		False negative rate: 0.047619047619047616
# 		Recall: 0.9523809523809523
# 		Precision: 0.9523809523809523
# 		F1: 0.9523809523809523
# 		Accuracy: 0.9649122807017544
# 		Error Rate: 0.03508771929824561
# 		Balance Accuracy: 0.9623015873015872
# 		True skill statistics: 0.9246031746031745
# 		Heidke skill score: 0.9246031746031746
# 	SVM model result:
# 		True negative: 35.0
# 		False positive: 1.0
# 		False negative: 0.0
# 		True positive: 21.0
# 		True positive rate: 1.0
# 		True negative rate: 0.9722222222222222
# 		False positive rate: 0.027777777777777776
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.9545454545454546
# 		F1: 0.9767441860465116
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9861111111111112
# 		True skill statistics: 0.9722222222222222
# 		Heidke skill score: 0.962671905697446
# Epoch 1/5
# 26/26 [==============================] - 7s 59ms/step - loss: 5.6887 - accuracy: 0.6270 - val_loss: 5.6181 - val_accuracy: 0.6316
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6887 - accuracy: 0.6270 - val_loss: 5.6181 - val_accuracy: 0.6316
# Epoch 3/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6887 - accuracy: 0.6270 - val_loss: 5.6181 - val_accuracy: 0.6316
# Epoch 4/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.6887 - accuracy: 0.6270 - val_loss: 5.6181 - val_accuracy: 0.6316
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6887 - accuracy: 0.6270 - val_loss: 5.6181 - val_accuracy: 0.6316
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 21.0
# 		False negative: 0.0
# 		True positive: 36.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.631578947368421
# 		F1: 0.7741935483870968
# 		Accuracy: 0.631578947368421
# 		Error Rate: 0.3684210526315789
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         |        TNR         |         FPR          |         FNR          |       recall       |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 35.0 | 1.0  | 1.0 | 20.0 | 0.9523809523809523 | 0.9722222222222222 | 0.027777777777777776 | 0.047619047619047616 | 0.9523809523809523 | 0.9523809523809523 | 0.9523809523809523 | 0.9649122807017544 | 0.03508771929824561  | 0.9623015873015872 | 0.9246031746031745 | 0.9246031746031746 |
# |     SVM      | 35.0 | 1.0  | 0.0 | 21.0 |        1.0         | 0.9722222222222222 | 0.027777777777777776 |         0.0          |        1.0         | 0.9545454545454546 | 0.9767441860465116 | 0.9824561403508771 | 0.017543859649122806 | 0.9861111111111112 | 0.9722222222222222 | 0.962671905697446  |
# |     lstm     | 0.0  | 21.0 | 0.0 | 36.0 |        1.0         |        0.0         |         1.0          |         0.0          |        1.0         | 0.631578947368421  | 0.9767441860465116 | 0.631578947368421  |  0.3684210526315789  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+--------------------+----------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 4
# 	Random Forest model result:
# 		True negative: 33.0
# 		False positive: 2.0
# 		False negative: 1.0
# 		True positive: 21.0
# 		True positive rate: 0.9545454545454546
# 		True negative rate: 0.9428571428571428
# 		False positive rate: 0.05714285714285714
# 		False negative rate: 0.045454545454545456
# 		Recall: 0.9545454545454546
# 		Precision: 0.9130434782608695
# 		F1: 0.9333333333333333
# 		Accuracy: 0.9473684210526315
# 		Error Rate: 0.05263157894736842
# 		Balance Accuracy: 0.9487012987012987
# 		True skill statistics: 0.8974025974025974
# 		Heidke skill score: 0.8898905344494527
# 	SVM model result:
# 		True negative: 35.0
# 		False positive: 0.0
# 		False negative: 1.0
# 		True positive: 21.0
# 		True positive rate: 0.9545454545454546
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.045454545454545456
# 		Recall: 0.9545454545454546
# 		Precision: 1.0
# 		F1: 0.9767441860465116
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9772727272727273
# 		True skill statistics: 0.9545454545454546
# 		Heidke skill score: 0.962671905697446
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 10s 76ms/step - loss: 5.6589 - accuracy: 0.6289 - val_loss: 5.8857 - val_accuracy: 0.6140
# Epoch 2/5
# 26/26 [==============================] - 0s 10ms/step - loss: 5.6589 - accuracy: 0.6289 - val_loss: 5.8857 - val_accuracy: 0.6140
# Epoch 3/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6589 - accuracy: 0.6289 - val_loss: 5.8857 - val_accuracy: 0.6140
# Epoch 4/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6589 - accuracy: 0.6289 - val_loss: 5.8857 - val_accuracy: 0.6140
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6589 - accuracy: 0.6289 - val_loss: 5.8857 - val_accuracy: 0.6140
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 22.0
# 		False negative: 0.0
# 		True positive: 35.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.6140350877192983
# 		F1: 0.7608695652173914
# 		Accuracy: 0.6140350877192983
# 		Error Rate: 0.38596491228070173
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         |        TNR         |         FPR         |         FNR          |       recall       |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 33.0 | 2.0  | 1.0 | 21.0 | 0.9545454545454546 | 0.9428571428571428 | 0.05714285714285714 | 0.045454545454545456 | 0.9545454545454546 | 0.9130434782608695 | 0.9333333333333333 | 0.9473684210526315 | 0.05263157894736842  | 0.9487012987012987 | 0.8974025974025974 | 0.8898905344494527 |
# |     SVM      | 35.0 | 0.0  | 1.0 | 21.0 | 0.9545454545454546 |        1.0         |         0.0         | 0.045454545454545456 | 0.9545454545454546 |        1.0         | 0.9767441860465116 | 0.9824561403508771 | 0.017543859649122806 | 0.9772727272727273 | 0.9545454545454546 | 0.962671905697446  |
# |     lstm     | 0.0  | 22.0 | 0.0 | 35.0 |        1.0         |        0.0         |         1.0         |         0.0          |        1.0         | 0.6140350877192983 | 0.9767441860465116 | 0.6140350877192983 | 0.38596491228070173  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+--------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 5
# 	Random Forest model result:
# 		True negative: 34.0
# 		False positive: 0.0
# 		False negative: 4.0
# 		True positive: 19.0
# 		True positive rate: 0.8260869565217391
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.17391304347826086
# 		Recall: 0.8260869565217391
# 		Precision: 1.0
# 		F1: 0.9047619047619048
# 		Accuracy: 0.9298245614035088
# 		Error Rate: 0.07017543859649122
# 		Balance Accuracy: 0.9130434782608696
# 		True skill statistics: 0.8260869565217391
# 		Heidke skill score: 0.85
# 	SVM model result:
# 		True negative: 34.0
# 		False positive: 0.0
# 		False negative: 3.0
# 		True positive: 20.0
# 		True positive rate: 0.8695652173913043
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.13043478260869565
# 		Recall: 0.8695652173913043
# 		Precision: 1.0
# 		F1: 0.9302325581395349
# 		Accuracy: 0.9473684210526315
# 		Error Rate: 0.05263157894736842
# 		Balance Accuracy: 0.9347826086956521
# 		True skill statistics: 0.8695652173913043
# 		Heidke skill score: 0.8883082952318746
# Epoch 1/5
# 26/26 [==============================] - 8s 79ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 3/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 4/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 5/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 23.0
# 		False negative: 0.0
# 		True positive: 34.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.5964912280701754
# 		F1: 0.7472527472527473
# 		Accuracy: 0.5964912280701754
# 		Error Rate: 0.40350877192982454
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         | TNR | FPR |         FNR         |       recall       |     precision      |         F1         |      accuracy      |          ER         |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# | RandomForest | 34.0 | 0.0  | 4.0 | 19.0 | 0.8260869565217391 | 1.0 | 0.0 | 0.17391304347826086 | 0.8260869565217391 |        1.0         | 0.9047619047619048 | 0.9298245614035088 | 0.07017543859649122 | 0.9130434782608696 | 0.8260869565217391 |        0.85        |
# |     SVM      | 34.0 | 0.0  | 3.0 | 20.0 | 0.8695652173913043 | 1.0 | 0.0 | 0.13043478260869565 | 0.8695652173913043 |        1.0         | 0.9302325581395349 | 0.9473684210526315 | 0.05263157894736842 | 0.9347826086956521 | 0.8695652173913043 | 0.8883082952318746 |
# |     lstm     | 0.0  | 23.0 | 0.0 | 34.0 |        1.0         | 0.0 | 1.0 |         0.0         |        1.0         | 0.5964912280701754 | 0.9302325581395349 | 0.5964912280701754 | 0.40350877192982454 |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 6
# 	Random Forest model result:
# 		True negative: 36.0
# 		False positive: 1.0
# 		False negative: 0.0
# 		True positive: 20.0
# 		True positive rate: 1.0
# 		True negative rate: 0.972972972972973
# 		False positive rate: 0.02702702702702703
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.9523809523809523
# 		F1: 0.975609756097561
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9864864864864865
# 		True skill statistics: 0.972972972972973
# 		Heidke skill score: 0.9619238476953907
# 	SVM model result:
# 		True negative: 37.0
# 		False positive: 0.0
# 		False negative: 1.0
# 		True positive: 19.0
# 		True positive rate: 0.95
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.05
# 		Recall: 0.95
# 		Precision: 1.0
# 		F1: 0.9743589743589743
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.975
# 		True skill statistics: 0.95
# 		Heidke skill score: 0.961038961038961
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 9s 80ms/step - loss: 5.7185 - accuracy: 0.6250 - val_loss: 5.3506 - val_accuracy: 0.6491
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7185 - accuracy: 0.6250 - val_loss: 5.3506 - val_accuracy: 0.6491
# Epoch 3/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.7185 - accuracy: 0.6250 - val_loss: 5.3506 - val_accuracy: 0.6491
# Epoch 4/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7185 - accuracy: 0.6250 - val_loss: 5.3506 - val_accuracy: 0.6491
# Epoch 5/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.7185 - accuracy: 0.6250 - val_loss: 5.3506 - val_accuracy: 0.6491
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 20.0
# 		False negative: 0.0
# 		True positive: 37.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.6491228070175439
# 		F1: 0.7872340425531915
# 		Accuracy: 0.6491228070175439
# 		Error Rate: 0.3508771929824561
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+------+-------------------+---------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+-------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  | TPR  |        TNR        |         FPR         | FNR  | recall |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS        |        HSS         |
# +--------------+------+------+-----+------+------+-------------------+---------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+-------------------+--------------------+
# | RandomForest | 36.0 | 1.0  | 0.0 | 20.0 | 1.0  | 0.972972972972973 | 0.02702702702702703 | 0.0  |  1.0   | 0.9523809523809523 | 0.975609756097561  | 0.9824561403508771 | 0.017543859649122806 | 0.9864864864864865 | 0.972972972972973 | 0.9619238476953907 |
# |     SVM      | 37.0 | 0.0  | 1.0 | 19.0 | 0.95 |        1.0        |         0.0         | 0.05 |  0.95  |        1.0         | 0.9743589743589743 | 0.9824561403508771 | 0.017543859649122806 |       0.975        |        0.95       | 0.961038961038961  |
# |     lstm     | 0.0  | 20.0 | 0.0 | 37.0 | 1.0  |        0.0        |         1.0         | 0.0  |  1.0   | 0.6491228070175439 | 0.9743589743589743 | 0.6491228070175439 |  0.3508771929824561  |        0.5         |        0.0        |        0.0         |
# +--------------+------+------+-----+------+------+-------------------+---------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+-------------------+--------------------+
#
#
#
# Fold 7
# 	Random Forest model result:
# 		True negative: 39.0
# 		False positive: 1.0
# 		False negative: 3.0
# 		True positive: 14.0
# 		True positive rate: 0.8235294117647058
# 		True negative rate: 0.975
# 		False positive rate: 0.025
# 		False negative rate: 0.17647058823529413
# 		Recall: 0.8235294117647058
# 		Precision: 0.9333333333333333
# 		F1: 0.875
# 		Accuracy: 0.9298245614035088
# 		Error Rate: 0.07017543859649122
# 		Balance Accuracy: 0.8992647058823529
# 		True skill statistics: 0.7985294117647058
# 		Heidke skill score: 0.8264840182648402
# 	SVM model result:
# 		True negative: 40.0
# 		False positive: 0.0
# 		False negative: 1.0
# 		True positive: 16.0
# 		True positive rate: 0.9411764705882353
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.058823529411764705
# 		Recall: 0.9411764705882353
# 		Precision: 1.0
# 		F1: 0.9696969696969697
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9705882352941176
# 		True skill statistics: 0.9411764705882353
# 		Heidke skill score: 0.9573672400897532
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 9s 69ms/step - loss: 5.8078 - accuracy: 0.6191 - val_loss: 4.5480 - val_accuracy: 0.7018
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.8078 - accuracy: 0.6191 - val_loss: 4.5480 - val_accuracy: 0.7018
# Epoch 3/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.8078 - accuracy: 0.6191 - val_loss: 4.5480 - val_accuracy: 0.7018
# Epoch 4/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.8078 - accuracy: 0.6191 - val_loss: 4.5480 - val_accuracy: 0.7018
# Epoch 5/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.8078 - accuracy: 0.6191 - val_loss: 4.5480 - val_accuracy: 0.7018
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 17.0
# 		False negative: 0.0
# 		True positive: 40.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.7017543859649122
# 		F1: 0.8247422680412371
# 		Accuracy: 0.7017543859649122
# 		Error Rate: 0.2982456140350877
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+-------+-------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         |  TNR  |  FPR  |         FNR          |       recall       |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+-------+-------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 39.0 | 1.0  | 3.0 | 14.0 | 0.8235294117647058 | 0.975 | 0.025 | 0.17647058823529413  | 0.8235294117647058 | 0.9333333333333333 |       0.875        | 0.9298245614035088 | 0.07017543859649122  | 0.8992647058823529 | 0.7985294117647058 | 0.8264840182648402 |
# |     SVM      | 40.0 | 0.0  | 1.0 | 16.0 | 0.9411764705882353 |  1.0  |  0.0  | 0.058823529411764705 | 0.9411764705882353 |        1.0         | 0.9696969696969697 | 0.9824561403508771 | 0.017543859649122806 | 0.9705882352941176 | 0.9411764705882353 | 0.9573672400897532 |
# |     lstm     | 0.0  | 17.0 | 0.0 | 40.0 |        1.0         |  0.0  |  1.0  |         0.0          |        1.0         | 0.7017543859649122 | 0.9696969696969697 | 0.7017543859649122 |  0.2982456140350877  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+-------+-------+----------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 8
# 	Random Forest model result:
# 		True negative: 33.0
# 		False positive: 1.0
# 		False negative: 0.0
# 		True positive: 23.0
# 		True positive rate: 1.0
# 		True negative rate: 0.9705882352941176
# 		False positive rate: 0.029411764705882353
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.9583333333333334
# 		F1: 0.9787234042553191
# 		Accuracy: 0.9824561403508771
# 		Error Rate: 0.017543859649122806
# 		Balance Accuracy: 0.9852941176470589
# 		True skill statistics: 0.9705882352941176
# 		Heidke skill score: 0.9638095238095238
# 	SVM model result:
# 		True negative: 34.0
# 		False positive: 0.0
# 		False negative: 0.0
# 		True positive: 23.0
# 		True positive rate: 1.0
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 1.0
# 		F1: 1.0
# 		Accuracy: 1.0
# 		Error Rate: 0.0
# 		Balance Accuracy: 1.0
# 		True skill statistics: 1.0
# 		Heidke skill score: 1.0
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 8s 76ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 2/5
# 26/26 [==============================] - 0s 10ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 3/5
# 26/26 [==============================] - 0s 15ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 4/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# Epoch 5/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.6291 - accuracy: 0.6309 - val_loss: 6.1532 - val_accuracy: 0.5965
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 23.0
# 		False negative: 0.0
# 		True positive: 34.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.5964912280701754
# 		F1: 0.7472527472527473
# 		Accuracy: 0.5964912280701754
# 		Error Rate: 0.40350877192982454
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+-----+--------------------+----------------------+-----+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  | TPR |        TNR         |         FPR          | FNR | recall |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+-----+--------------------+----------------------+-----+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 33.0 | 1.0  | 0.0 | 23.0 | 1.0 | 0.9705882352941176 | 0.029411764705882353 | 0.0 |  1.0   | 0.9583333333333334 | 0.9787234042553191 | 0.9824561403508771 | 0.017543859649122806 | 0.9852941176470589 | 0.9705882352941176 | 0.9638095238095238 |
# |     SVM      | 34.0 | 0.0  | 0.0 | 23.0 | 1.0 |        1.0         |         0.0          | 0.0 |  1.0   |        1.0         |        1.0         |        1.0         |         0.0          |        1.0         |        1.0         |        1.0         |
# |     lstm     | 0.0  | 23.0 | 0.0 | 34.0 | 1.0 |        0.0         |         1.0          | 0.0 |  1.0   | 0.5964912280701754 |        1.0         | 0.5964912280701754 | 0.40350877192982454  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+-----+--------------------+----------------------+-----+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 9
# 	Random Forest model result:
# 		True negative: 33.0
# 		False positive: 0.0
# 		False negative: 2.0
# 		True positive: 22.0
# 		True positive rate: 0.9166666666666666
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.08333333333333333
# 		Recall: 0.9166666666666666
# 		Precision: 1.0
# 		F1: 0.9565217391304348
# 		Accuracy: 0.9649122807017544
# 		Error Rate: 0.03508771929824561
# 		Balance Accuracy: 0.9583333333333333
# 		True skill statistics: 0.9166666666666666
# 		Heidke skill score: 0.9272030651340997
# 	SVM model result:
# 		True negative: 33.0
# 		False positive: 0.0
# 		False negative: 3.0
# 		True positive: 21.0
# 		True positive rate: 0.875
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.125
# 		Recall: 0.875
# 		Precision: 1.0
# 		F1: 0.9333333333333333
# 		Accuracy: 0.9473684210526315
# 		Error Rate: 0.05263157894736842
# 		Balance Accuracy: 0.9375
# 		True skill statistics: 0.875
# 		Heidke skill score: 0.8901734104046243
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 10s 107ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 3/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 4/5
# 26/26 [==============================] - 0s 8ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.5993 - accuracy: 0.6328 - val_loss: 6.4207 - val_accuracy: 0.5789
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 24.0
# 		False negative: 0.0
# 		True positive: 33.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.5789473684210527
# 		F1: 0.7333333333333333
# 		Accuracy: 0.5789473684210527
# 		Error Rate: 0.42105263157894735
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  |        TPR         | TNR | FPR |         FNR         |       recall       |     precision      |         F1         |      accuracy      |          ER         |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# | RandomForest | 33.0 | 0.0  | 2.0 | 22.0 | 0.9166666666666666 | 1.0 | 0.0 | 0.08333333333333333 | 0.9166666666666666 |        1.0         | 0.9565217391304348 | 0.9649122807017544 | 0.03508771929824561 | 0.9583333333333333 | 0.9166666666666666 | 0.9272030651340997 |
# |     SVM      | 33.0 | 0.0  | 3.0 | 21.0 |       0.875        | 1.0 | 0.0 |        0.125        |       0.875        |        1.0         | 0.9333333333333333 | 0.9473684210526315 | 0.05263157894736842 |       0.9375       |       0.875        | 0.8901734104046243 |
# |     lstm     | 0.0  | 24.0 | 0.0 | 33.0 |        1.0         | 0.0 | 1.0 |         0.0         |        1.0         | 0.5789473684210527 | 0.9333333333333333 | 0.5789473684210527 | 0.42105263157894735 |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+--------------------+-----+-----+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
#
#
#
# Fold 10
# 	Random Forest model result:
# 		True negative: 36.0
# 		False positive: 0.0
# 		False negative: 1.0
# 		True positive: 19.0
# 		True positive rate: 0.95
# 		True negative rate: 1.0
# 		False positive rate: 0.0
# 		False negative rate: 0.05
# 		Recall: 0.95
# 		Precision: 1.0
# 		F1: 0.9743589743589743
# 		Accuracy: 0.9821428571428571
# 		Error Rate: 0.017857142857142856
# 		Balance Accuracy: 0.975
# 		True skill statistics: 0.95
# 		Heidke skill score: 0.9606741573033708
# 	SVM model result:
# 		True negative: 35.0
# 		False positive: 1.0
# 		False negative: 0.0
# 		True positive: 20.0
# 		True positive rate: 1.0
# 		True negative rate: 0.9722222222222222
# 		False positive rate: 0.027777777777777776
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.9523809523809523
# 		F1: 0.975609756097561
# 		Accuracy: 0.9821428571428571
# 		Error Rate: 0.017857142857142856
# 		Balance Accuracy: 0.9861111111111112
# 		True skill statistics: 0.9722222222222222
# 		Heidke skill score: 0.9615384615384616
#
#
#
# Epoch 1/5
# 26/26 [==============================] - 7s 67ms/step - loss: 5.7073 - accuracy: 0.6257 - val_loss: 5.4462 - val_accuracy: 0.6429
# Epoch 2/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7073 - accuracy: 0.6257 - val_loss: 5.4462 - val_accuracy: 0.6429
# Epoch 3/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7073 - accuracy: 0.6257 - val_loss: 5.4462 - val_accuracy: 0.6429
# Epoch 4/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7073 - accuracy: 0.6257 - val_loss: 5.4462 - val_accuracy: 0.6429
# Epoch 5/5
# 26/26 [==============================] - 0s 9ms/step - loss: 5.7073 - accuracy: 0.6257 - val_loss: 5.4462 - val_accuracy: 0.6429
# LSTM:
#
#
# 		True negative: 0.0
# 		False positive: 20.0
# 		False negative: 0.0
# 		True positive: 36.0
# 		True positive rate: 1.0
# 		True negative rate: 0.0
# 		False positive rate: 1.0
# 		False negative rate: 0.0
# 		Recall: 1.0
# 		Precision: 0.6428571428571429
# 		F1: 0.782608695652174
# 		Accuracy: 0.6428571428571429
# 		Error Rate: 0.35714285714285715
# 		Balance Accuracy: 0.5
# 		True skill statistics: 0.0
# 		Heidke skill score: 0.0
# +--------------+------+------+-----+------+------+--------------------+----------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# |    Model     |  TN  |  FP  |  FN |  TP  | TPR  |        TNR         |         FPR          | FNR  | recall |     precision      |         F1         |      accuracy      |          ER          |         BA         |        TSS         |        HSS         |
# +--------------+------+------+-----+------+------+--------------------+----------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# | RandomForest | 36.0 | 0.0  | 1.0 | 19.0 | 0.95 |        1.0         |         0.0          | 0.05 |  0.95  |        1.0         | 0.9743589743589743 | 0.9821428571428571 | 0.017857142857142856 |       0.975        |        0.95        | 0.9606741573033708 |
# |     SVM      | 35.0 | 1.0  | 0.0 | 20.0 | 1.0  | 0.9722222222222222 | 0.027777777777777776 | 0.0  |  1.0   | 0.9523809523809523 | 0.975609756097561  | 0.9821428571428571 | 0.017857142857142856 | 0.9861111111111112 | 0.9722222222222222 | 0.9615384615384616 |
# |     lstm     | 0.0  | 20.0 | 0.0 | 36.0 | 1.0  |        0.0         |         1.0          | 0.0  |  1.0   | 0.6428571428571429 | 0.975609756097561  | 0.6428571428571429 | 0.35714285714285715  |        0.5         |        0.0         |        0.0         |
# +--------------+------+------+-----+------+------+--------------------+----------------------+------+--------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
